# %% [markdown]
# # Тема проекта: HR Аналитика для прогнозирования статуса сотрудника

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
# Собирать данные такими опросниками не так легко: компания большая, и всех сотрудников надо сначала оповестить об опросе, а затем проследить, что все его прошли.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Данные для задачи №1: **Предсказание уровня удовлетворённости сотрудника**
#
# id — уникальный идентификатор сотрудника;
# dept — отдел, в котором работает сотрудник;
# level — уровень занимаемой должности;
# workload — уровень загруженности сотрудника;
# employment_years — длительность работы в компании (в годах);
# last_year_promo — показывает, было ли повышение за последний год;
# last_year_violations — показывает, нарушал ли сотрудник трудовой договор за последний год;
# supervisor_evaluation — оценка качества работы сотрудника, которую дал руководитель;
# salary — ежемесячная зарплата сотрудника;
# job_satisfaction_rate — уровень удовлетворённости сотрудника работой в компании, целевой признак.
#
# Тренировочная выборка:
# *train_job_satisfaction_rate.csv*
# Входные признаки тестовой выборки:
# *test_features.csv*
# Целевой признак тестовой выборки:
# *test_target_job_satisfaction_rate.csv*
#
# Данные для задачи №2 **Предсказание увольнения сотрудника из компании**
#
# Для этой задачи использовать те же входные признаки, что и в задаче №1.
# NB! Целевой признак отличается: это quit — увольнение сотрудника из компании.
#
# Тренировочная выборка:
# *train_quit.csv*
# Входные признаки тестовой выборки те же, что и в прошлой задаче:
# *test_features.csv*
# Целевой признак тестовой выборки:
# *test_target_quit.csv*

# %% [markdown]
# ## Цель исследования

# %% [markdown]
# 1. Построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# 2. Построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании

# %% [markdown]
# ## Ход исследования

# %% [markdown]
# Для исследования поставленных целей необходимо выполнить следующие шаги:
#
# **Задача №1: Предсказание уровня удовлетворённости сотрудника**
#
# **Шаг 1. Загрузка данных**
# Загрузить файлы с данными:
# Тренировочная выборка:
# train_job_satisfaction_rate.csv
# Входные признаки тестовой выборки:
# test_features.csv
# Целевой признак тестовой выборки:
# test_target_job_satisfaction_rate.csv
#
# **Шаг 2. Предобработка данных**
# Изучить данные и сделать выводы. Выполнить предобработку. Заполнить пропуски в пайплайне.
#
# **Шаг 3. Исследовательский анализ данных**
# Исследовать признаки и сделать выводы о том, как их нужно подготовить.
#
# **Шаг 4. Подготовка данных**
# Подготовку признаков выполнить в пайплайне, дополнив пайплайн шага предобработки. При кодировании учитывать особенности признаков моделей и использовать как минимум два кодировщика.
#
# **Шаг 5. Обучение моделей**
# Обучить две модели. Взять одну линейную модель, а в качестве второй — дерево решений. Подобрать гиперпараметры для одной модели.
# Выберать лучшую модель и проверить её качество. Выбор делаать на основе новой метрики — SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»).
# Метрика SMAPE:
#
# ![image.png](attachment:image.png)
#
# Написать функцию, которая принимает на вход массивы NumPy или объекты Series в pandas и возвращает значение метрики SMAPE.
# Использовать эту метрику при подборе гиперпараметров и оценке качества моделей.
#
# **Критерий успеха: SMAPE ≤15 на тестовой выборке**
# В решении сохранить работу со всеми моделями и сделайть выводы.
#
# **Шаг 6. Оформление выводов**
# Сделать промежуточные выводы о том, какая модель справилась лучше и почему.
#
# **Задача №2: Предсказание увольнения сотрудника из компании**
#
# **Шаг 1. Загрузка данных**
# Загрузить данные из файлов:
# Тренировочная выборка:
# train_quit.csv
# Входные признаки тестовой выборки те же, что и в прошлой задаче:
# test_features.csv
# Целевой признак тестовой выборки:
# test_target_quit.csv
#
# **Шаг 2. Предобработка данных**
# Изучить данные и заполнить пропуски в пайплайне.
#
# **Шаг 3. Исследовательский анализ данных**
# 3.1. Провести исследовательский анализ данных.
# 3.2. Составить портрет «уволившегося сотрудника». Нужно знать в каком отделе с большей вероятностью работает уволившийся сотрудник и какой у него уровень загруженности. Сравнить среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании.
# 3.3. Аналитики утверждают, что *ровень удовлетворённости сотрудника работой в компании влияет на то, уволится ли сотрудник*.
# Проверить это утверждение: визуализировать и сравнить распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников. Использовать данные с обоими целевыми признаками тестовой выборки.
#
# **Шаг 4. Добавление нового входного признака**
# Допустим, job_satisfaction_rate и quit действительно связаны и вы получили необходимое значение метрики в первой задаче. Тогда добавьте job_satisfaction_rate, предсказанный лучшей моделью первой задачи, к входным признакам второй задачи.
#
# **Шаг 5. Подготовка данных**
# Подготовить признаки так же, как и в первой задаче: выполнить подготовку в пайплайне, дополнив пайплайн предобработки. При кодировании учитываать особенности признаков и моделей и использовать как минимум два кодировщика.
#
# **Шаг 6. Обучение модели**
# Обучить три модели. Для двух из них подобрать гиперпараметры. Проверить качество лучшей модели.
# Метрика оценки качества в задаче — **ROC-AUC**.
# Критерий успеха: **ROC-AUC ≥0.91 на тестовой выборке**.
#
# **Шаг 7. Выводы**
# Сделать промежуточные выводы о том, какая модель справилась лучше и почему.
#
# **Общий вывод**
# - описать задачу;
# - описать этапы работы;
# - добавить выводы и доволнительные предложения для бизнеса.

# %% [markdown]
# ### Задача №1

# %% [markdown]
# ### 1. Загрузка данных

# %%
# Загрузка библиотек, которые могут понадобиться
# !pip install phik
# !pip install --upgrade scikit-learn==1.4
# !pip install shap
# !pip install yellowbrick

# %%
# Загрузка библиотек
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import statsmodels.api as sm
import warnings
import phik
#import shap

from scipy import stats as st
from scipy.stats import ttest_ind
from scipy.stats import shapiro
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVC
from sklearn.tree import (DecisionTreeRegressor, DecisionTreeClassifier)
from sklearn.metrics import (mean_absolute_percentage_error, roc_auc_score, make_scorer, accuracy_score, 
                             recall_score, precision_score, classification_report)
from sklearn.linear_model import (LogisticRegression, LinearRegression)
from sklearn.model_selection import (train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV)
from sklearn.preprocessing import (StandardScaler, OneHotEncoder, OrdinalEncoder, MinMaxScaler, LabelEncoder, RobustScaler)
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from yellowbrick.classifier.rocauc import roc_auc
from phik import resources, report
from phik.report import plot_correlation_matrix
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.inspection import permutation_importance
from IPython.display import display
from IPython.core.getipython import get_ipython
from sklearn.cluster import KMeans
from sklearn.dummy import DummyClassifier
from sklearn.dummy import DummyRegressor
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
# Загрузка датафреймов
train_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/train_job_satisfaction_rate.csv') #Тренировочная выборка
test_features = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv') #Входные признаки тестовой выборки
test_target_job_satisfaction_rate = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_job_satisfaction_rate.csv') #Целевой признак тестовой выборки

# %%
# Общая информация для датасета train_job_satisfaction_rate
train_job_satisfaction_rate.info()
train_job_satisfaction_rate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# ...

# %% [markdown]
# В датасете 10 колонок и 4000 строк
# В колонках dept и level строк меньше 4000, возможно это пропущенные значения
# Типы данных соответствуют своему описанию

# %%
# Общая информация для датасета test_features
test_features.info()
test_features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %% [markdown]
# В датасете 9 колонок и 2000 строк
# В колонках dept и level строк меньше 2000, возможно это пропущенные значения
# Типы данных соответсвтуют своему описанию

# %%
# Общая информация для датасета test_target_job_satisfaction_rate
test_target_job_satisfaction_rate.info()
test_target_job_satisfaction_rate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %% [markdown]
# В датасете 2 колоноки и 2000 строк
# Типы данных соответсвтуют своему описанию

# %% [markdown]
# ### Вывод

# %% [markdown]
# Было загружено 3 датасета: train_job_satisfaction_rate.csv, test_features.csv, test_target_job_satisfaction_rate.csv
# Вероятно в датасетах train_job_satisfaction_rate.csv и test_features.csv есть пропуски в столбцах dept и level.
# Типы данных во всех датасетах соответсвуют действительности.
# Следующим шагом необходимо провести проверку данных на пропуски и дубликаты

# %% [markdown]
# ### 2. Предобработка данных

# %%
# Создание словаря
dataframes = {
    'train_job_satisfaction_rate': train_job_satisfaction_rate,
    'test_features': test_features,
    'test_target_job_satisfaction_rate': test_target_job_satisfaction_rate
}

# %%
# Функция для вывода информации о пропусках
def print_missing_values(df_dict):
    for name, df in df_dict.items():
        print(f"Пропуски в датафрейме {name}:")
        print(df.isnull().sum())
        print("\n")

# %%
# Вызов функции для вывода пропусков
print_missing_values(dataframes)
# Out:
# Пропуски в датафрейме train_job_satisfaction_rate:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64
#
#
# Пропуски в датафрейме test_features:
# id                       0
# dept                     2
# level                    1
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64
#
#
# Пропуски в датафрейме test_target_job_satisfaction_rate:
# id                       0
# job_satisfaction_rate    0
# dtype: int64

# %%
# Вывод пропусков датафрейма train_job_satisfaction_rate
display(train_job_satisfaction_rate[train_job_satisfaction_rate.dept.isnull()])
train_job_satisfaction_rate[train_job_satisfaction_rate.level.isnull()]
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1526  694746  NaN  junior   medium                 5              no
# 1630  814624  NaN  junior   medium                 3              no
# 1633  475114  NaN  junior     high                 4              no
# 2781  497243  NaN  junior   medium                 1              no
# 2975  168668  NaN  junior      low                 3              no
# 3866  641150  NaN  junior      low                 3              no
#
#      last_year_violations  supervisor_evaluation  salary  \
# 1526                   no                      4   21600
# 1630                   no                      4   24000
# 1633                   no                      4   31200
# 2781                   no                      3   26400
# 2975                   no                      4   18000
# 3866                  yes                      4   12000
#
#       job_satisfaction_rate
# 1526                   0.62
# ...

# %%
# Вывод пропусков датафрейма test_features
display(test_features[test_features.dept.isnull()])
test_features[test_features.level.isnull()]
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 191   609865  NaN  junior   medium                 1              no
# 1196  832342  NaN  junior   medium                 1              no
#
#      last_year_violations  supervisor_evaluation  salary
# 191                    no                      1   20400
# 1196                   no                      4   28800
#          id   dept level workload  employment_years last_year_promo  \
# 312  471990  sales   NaN      low                 1              no
#
#     last_year_violations  supervisor_evaluation  salary
# 312                   no                      3   12000

# %%
# Обзор уникальных значений
train_job_satisfaction_rate['dept'].unique()
# Out:
# array(['sales', 'hr', 'technology', 'purchasing', 'marketing', nan],
#       dtype=object)

# %%
# Обзор уникальных значений
train_job_satisfaction_rate['level'].unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %%
# Обзор уникальных значений
test_features['dept'].unique()
# Out:
# array(['marketing', 'hr', 'sales', 'purchasing', 'technology', nan, ' '],
#       dtype=object)

# %%
# Обзор уникальных значений
test_features['level'].unique()
# Out:
# array(['junior', 'middle', 'sinior', nan], dtype=object)

# %% [markdown]
# Имеются пропуски типа nan.
# Имеется ' ' значения.
# Не корректно написаны должность в колонке level

# %%
# Исправляю артефакты
train_job_satisfaction_rate['level'] = train_job_satisfaction_rate['level'].str.replace('sinior', 'senior')
test_features['level'] = test_features['level'].str.replace('sinior', 'senior')

# %%
# Вывод количества уникальных значений
display(train_job_satisfaction_rate['dept'].value_counts().reset_index())
display(test_features['dept'].value_counts().reset_index())
# Out:
#         index  dept
# 0       sales  1512
# 1  technology   866
# 2  purchasing   610
# 3   marketing   550
# 4          hr   456
#         index  dept
# 0       sales   763
# 1  technology   455
# 2   marketing   279
# 3  purchasing   273
# 4          hr   227
# 5                 1

# %%
# Исправляю артефакты
test_features['level'] = test_features['level'].str.replace(' ', 'sales')

# %%
# Вывод количества уникальных значений
display(train_job_satisfaction_rate['level'].value_counts().reset_index())
display(test_features['level'].value_counts().reset_index())
# Out:
#     index  level
# 0  junior   1894
# 1  middle   1744
# 2  senior    358
#     index  level
# 0  junior    974
# 1  middle    854
# 2  senior    171

# %%
# Определение категориальных и числовых признаков
categorical_features = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
numerical_features = ['employment_years', 'supervisor_evaluation', 'salary']

# %%
# Создание пайплайна для категориальных признаков
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent'))
])

# %%
# Применение пайплайна к столбцам 'level' и 'dept' в train_job_satisfaction_rate
train_job_satisfaction_rate[['level', 'dept']] = categorical_transformer.fit_transform(train_job_satisfaction_rate[['level', 'dept']])

# Применение обученного пайплайна к столбцам 'level' и 'dept' в test_features
test_features[['level', 'dept']] = categorical_transformer.transform(test_features[['level', 'dept']])

# %%
# Проверка, что пропуски заполнены
print(train_job_satisfaction_rate[['level', 'dept']].isnull().sum())
print(test_features[['level', 'dept']].isnull().sum())
# Out:
# level    0
# dept     0
# dtype: int64
# level    0
# dept     0
# dtype: int64

# %%
# Функция для вывода информации о дубликатах
def print_duplicates(df_dict):
    for name, df in df_dict.items():
        print(f"Явные дубликаты в датафрейме {name}:")
        duplicates = df[df.duplicated()]
        if not duplicates.empty:
            print(duplicates)
        else:
            print("Явных дубликатов нет")
        print("\n")

# Вызов функции для вывода дубликатов
print_duplicates(dataframes)
# Out:
# Явные дубликаты в датафрейме train_job_satisfaction_rate:
# Явных дубликатов нет
#
#
# Явные дубликаты в датафрейме test_features:
# Явных дубликатов нет
#
#
# Явные дубликаты в датафрейме test_target_job_satisfaction_rate:
# Явных дубликатов нет

# %%
# Функция для нахождения неявных дубликатов
def find_implicit_duplicates(df_dict):
    for name, df in df_dict.items():
        print(f"Неявные дубликаты в датафрейме {name}:")
        
        #приведение строковых колонок к нижнему регистру и удаление пробелов
        df_cleaned = df.apply(lambda col: col.map(lambda x: x.strip().lower() if isinstance(x, str) else x))
        
        #нахождение дубликатов
        duplicates = df_cleaned[df_cleaned.duplicated()]
        
        if not duplicates.empty:
            print(duplicates)
        else:
            print("Нет неявных дубликатов")
        print("\n")

# Вызов функции для нахождения неявных дубликатов
find_implicit_duplicates(dataframes)
# Out:
# Неявные дубликаты в датафрейме train_job_satisfaction_rate:
# Нет неявных дубликатов
#
#
# Неявные дубликаты в датафрейме test_features:
# Нет неявных дубликатов
#
#
# Неявные дубликаты в датафрейме test_target_job_satisfaction_rate:
# Нет неявных дубликатов

# %%
# Объединение датафреймов по столбцу 'id'
test_data = pd.merge(test_features, test_target_job_satisfaction_rate, on='id')

# %%
# Проверка первых нескольких строк объединенного датафрейма
test_data.info()
test_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 171.9+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Была создана функция для вывода пропущенных значений.
# При обработке данных в датафреймах train_job_satisfaction_rate и test_features были обнаружены пропущенные значения типа NaN.
# В столбцах level датафрейма train_job_satisfaction_rate и test_features, значения s<font color='red'>i</font>nior были изменены на senior.
# В столбце dept датафрейма test_features, значение ' ' было изменено на часто встречаемое sales.
# Пустые значения в столбцах level и dept в датафреймах train_job_satisfaction_rate и test_features были заполнены с использованием пайплайна.
# Датафреймы проверены на наличие явных и неявных дубликатов. Дубликаты отсутствуют.
# Датафреймы test_features и test_target_job_satisfaction_rate были объединены с использованием функции merge по признаку id с созданием нового датафрейма test_data.

# %% [markdown]
# ### 3. Исследовательский анализ данных

# %%
# Создание нового словаря
dataframes = {
    'train_job_satisfaction_rate': train_job_satisfaction_rate,
    'test_data': test_data
}

# %%
# Функция для построения гистограммы распределения
def plot_histogram(df, column):
    plt.figure(figsize=(10, 6))
    sns.histplot(df[column], kde=True)
    plt.title(f'Гистограмма распределения для категории {column}')
    plt.xlabel(column)
    plt.ylabel('Частота')
    plt.show()

# Функция для построения гистограммы размаха (boxplot)
def plot_boxplot(df, column):
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[column])
    plt.title(f'Гистограмма размаха для категории {column}')
    plt.xlabel(column)
    plt.show()

# Функция для построения частоты встречаемости для дискретных признаков
def plot_countplot(df, column):
    plt.figure(figsize=(10, 6))
    sns.countplot(x=df[column])
    plt.title(f'Частота встречаемости для категории {column}')
    plt.xlabel(column)
    plt.ylabel('Частота')
    plt.show()

# Функция для построения круговой диаграммы для категориальных признаков
def plot_pie_chart(df, column):
    plt.figure(figsize=(10, 6))
    df[column].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.title(f'Круговая диаграмма для категории {column}')
    plt.ylabel('')
    plt.show()

# %%
# Функция для построения всех графиков для датафрейма
def plot_all_graphs(df):
    print("Построение графиков для датафрейма:")
    for column in df.columns:
        if column == 'id':
            continue
        if pd.api.types.is_numeric_dtype(df[column]):
            unique_values = df[column].nunique()
            if unique_values < 20:  # Условие для дискретных признаков
                print(f"Построение графиков для дискретного признака {column}:")
                plot_countplot(df, column)
            else:  # Условие для непрерывных признаков
                print(f"Построение графиков для непрерывного признака {column}:")
                plot_histogram(df, column)
                plot_boxplot(df, column)
        else:
            print(f"Построение графиков для категориального признака {column}:")
            plot_pie_chart(df, column)

# %%
# Вызов функции для построения всех графиков для каждого датафрейма
plot_all_graphs(dataframes['train_job_satisfaction_rate'])
# Out:
# Построение графиков для датафрейма:
# Построение графиков для категориального признака dept:
# Построение графиков для категориального признака level:
# Построение графиков для категориального признака workload:
# Построение графиков для дискретного признака employment_years:
# Построение графиков для категориального признака last_year_promo:
# Построение графиков для категориального признака last_year_violations:
# Построение графиков для дискретного признака supervisor_evaluation:
# Построение графиков для непрерывного признака salary:
# Построение графиков для непрерывного признака job_satisfaction_rate:

# %% [markdown]
# Персонал распределен по отделам неравномерно. Больше всего приходится на отдел продаж.
# Уровни middle и junior почти равны. Уровень senior самый малочисленный.
# Больше всего рабочей нагрузки приходится на уровень medium.
# Стаж работы распределен логично, больше всего сотрудников, которые работают от 1 года. Сотрудники, которые работают уже 10 лет значительно меньшее количество, скорее всего это связано с тем, что они занимают более высокие и хорошо оплачиваемые должности.
# В прошлогодней акции участвовало очень мало человек, всего 3% от всего числа.
# Нарушений трудового договора не много от всего числа сотрудников 14%.
# Чаще всего руководители оценивают сотрудников на 4 и 3.
# Заработная смещена влево в сторону меньшей зарплаты. Большинство сотрудников получает зарплаты в диапазоне 20 000 - 40 000. Зарплаты выше 76 000 не являются вылетами, скорее всего их получают топ менеджеры.
# График удовлетворенности работой бимодальный. Имеются два ярко выраженных пика.

# %%
# Вызов функции для построения всех графиков для каждого датафрейма
plot_all_graphs(dataframes['test_data'])
# Out:
# Построение графиков для датафрейма:
# Построение графиков для категориального признака dept:
# Построение графиков для категориального признака level:
# Построение графиков для категориального признака workload:
# Построение графиков для дискретного признака employment_years:
# Построение графиков для категориального признака last_year_promo:
# Построение графиков для категориального признака last_year_violations:
# Построение графиков для дискретного признака supervisor_evaluation:
# Построение графиков для непрерывного признака salary:
# Построение графиков для непрерывного признака job_satisfaction_rate:

# %% [markdown]
# В тестовой выборке точно такое же распределение данных как в тренировочной

# %%
# Исключение колонки 'id'
train_data = train_job_satisfaction_rate.drop(columns=['id'])

# %%
# Проверка наличия дубликатов
duplicates = train_data.duplicated().sum()
print(f"Количество дубликатов в тренировочных данных: {duplicates}")
# Out:
# Количество дубликатов в тренировочных данных: 248

# %%
# Удаление дубликатов
train_data = train_data.drop_duplicates()

# %%
# Проверка размера датафрейма после удаления дубликатов
print("Размер датафрейма после удаления дубликатов:", train_data.shape)
# Out:
# Размер датафрейма после удаления дубликатов: (3752, 9)

# %%
# Указание непрерывных признаков
interval_cols = ['salary', 'job_satisfaction_rate']

# %%
# Расчет матрицы корреляции phik
phik_matrix = train_data.phik_matrix(interval_cols=interval_cols)

# %%
# Построение тепловой карты
plt.figure(figsize=(16, 12))
sns.heatmap(phik_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Тепловая карта матрицы корреляции Phik')
plt.show()

# %% [markdown]
# - Сильные корреляции:
#
# supervisor_evaluation и job_satisfaction_rate (0.76)
# workload и salary (0.79)
# level и salary (0.72)
# employment_years и level (0.68)
#
# - Умеренные корреляции:
#
# employment_years и job_satisfaction_rate (0.33)
# last_year_violations и job_satisfaction_rate (0.56)
#
# - Слабые корреляции:
#
# Большинство других признаков имеют слабую корреляцию с целевым признаком job_satisfaction_rate.

# %%
# Исключение колонки 'id'
df_test = test_data.drop(columns=['id'])

# %%
# Расчет матрицы корреляции phik
phik_matrix = df_test.phik_matrix(interval_cols=interval_cols)

# %%
# Построение тепловой карты
plt.figure(figsize=(16, 12))
sns.heatmap(phik_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Тепловая карта матрицы корреляции Phik')
plt.show()

# %% [markdown]
# - Сильные корреляции:
#
# supervisor_evaluation и job_satisfaction_rate (0.77)
# workload и salary (0.74)
# level и salary (0.75)
# employment_years и level (0.69)
#
# - Умеренные корреляции:
#
# employment_years и job_satisfaction_rate (0.31)
# last_year_violations и job_satisfaction_rate (0.55)
# last_year_promo и job_satisfaction_rate (0.34)
#
# - Слабые корреляции:
#
# Большинство других признаков имеют слабую корреляцию с целевым признаком job_satisfaction_rate.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для датафреймов train_job_satisfaction_rate и test_data были построены графики для анализа данных и тепловые карты корреляции.
# Признаки для дальнейшей работы будут подготовлены следующим образом.
#
# - Категориальные признаки:
#
# Использовать OneHotEncoder для кодирования категориальных признаков (dept, level, workload, last_year_promo, last_year_violations).
#
# - Дискретные признаки:
#
# Нормализовать или стандартизировать дискретные признаки (employment_years, supervisor_evaluation).
#
# - Непрерывные признаки:
#
# Нормализовать или стандартизировать непрерывные признаки (salary, job_satisfaction_rate).

# %% [markdown]
# ### 4. Подготовка данных

# %%
# Разделение категориальных признаков на те, которые будут кодироваться OneHotEncoder и OrdinalEncoder
onehot_features = ['dept']
ordinal_features = ['level', 'workload', 'last_year_promo', 'last_year_violations']

# %%
# Пайплайн для категориальных признаков, которые будут кодироваться OneHotEncoder
onehot_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])

# %%
# Пайплайн для категориальных признаков, которые будут кодироваться OrdinalEncoder
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# %%
# Пайплайн для числовых признаков
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# Объединение пайплайнов в ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('onehot', onehot_transformer, onehot_features),
        ('ordinal', ordinal_transformer, ordinal_features)
    ])

# %%
# Возвращение колонки 'id' в датафрейм
train_data = train_data.join(train_job_satisfaction_rate['id'])

# %%
# Размер датафрейма
train_data.shape
# Out:
# (3752, 10)

# %%
# Применение пайплайна к тренировочным данным
X_train = train_data.drop(columns=['id', 'job_satisfaction_rate'])

# %%
# Размер датафрейма
X_train.shape
# Out:
# (3752, 8)

# %%
# Применение пайплайна к тренировочным данным
X_train = train_data.drop(columns=['id', 'job_satisfaction_rate'])
y_train = train_data['job_satisfaction_rate']
X_train_prepared = preprocessor.fit_transform(X_train)

# Применение пайплайна к тестовым данным
X_test = test_data.drop(columns=['id'])
X_test_prepared = preprocessor.transform(X_test)
# Out:
# D:\programs\python\anakonda\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Проверка результата
print(X_train_prepared.shape)
print(X_test_prepared.shape)
# Out:
# (3752, 11)
# (2000, 11)

# %% [markdown]
# ### Вывод

# %% [markdown]
# На данном шаге была выполнена предобработка данных с использованием пайплайнов для различных типов признаков. Основные этапы и результаты предобработки данных можно резюмировать следующим образом:
#
# 1. Разделение категориальных признаков:
#
# - Категориальные признаки были разделены на две группы:
#
# Признаки, которые будут кодироваться с помощью OneHotEncoder: dept.
# Признаки, которые будут кодироваться с помощью OrdinalEncoder: last_year_promo, last_year_violations, level, workload.
#
# 2. Создание пайплайнов для категориальных признаков:
#
# - Для признаков, кодируемых с помощью OneHotEncoder, был создан пайплайн, включающий:
#
# Заполнение пропусков наиболее частым значением (SimpleImputer).
# Кодирование категориальных признаков (OneHotEncoder).
#
# - Для признаков, кодируемых с помощью OrdinalEncoder, был создан пайплайн, включающий:
#
# Заполнение пропусков наиболее частым значением (SimpleImputer).
# Кодирование категориальных признаков (OrdinalEncoder).
#
# 3. Создание пайплайна для числовых признаков:
#
# - Для числовых признаков был создан пайплайн, включающий:
#
# Заполнение пропусков средним значением (SimpleImputer).
# Нормализация признаков (StandardScaler).
#
# 4. Объединение пайплайнов в ColumnTransformer:
#
# Все созданные пайплайны были объединены в один общий пайплайн (ColumnTransformer), который обрабатывает числовые и категориальные признаки соответственно.
#
# 5. Применение пайплайна к тренировочным данным:
#
# Данные были разделены на признаки (X_train) и целевой признак (y_train).
# Общий пайплайн был применен к тренировочным данным для предобработки признаков.
#
# 6. Применение пайплайна к тестовым данным:
#
# Общий пайплайн был применен к тестовым данным для предобработки признаков.
# Проверка результата:
#
# Размеры преобразованных тренировочных данных: (3752, 11).
# Размеры преобразованных тестовых данных: (2000, 11).

# %% [markdown]
# ### 5. Обучение моделей

# %%
# Функция SMAPE (англ. symmetric mean absolute percentage error, «симметричное среднее абсолютное процентное отклонение»)
def smape(y_true, y_pred):
    return 100 * np.mean(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

# %%
# Кастомный скоррер для SMAPE
smape_scorer = make_scorer(smape, greater_is_better=False)

# %%
# Пайплайн для линейной модели
linear_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', LinearRegression())
])

# Оценка линейной модели на кросс-валидации
linear_scores = cross_val_score(linear_pipeline, X_train, y_train, cv=5, scoring=smape_scorer)
print(f"SMAPE для линейной модели на кросс-валидации: {-linear_scores.mean():.2f}")
# Out:
# SMAPE для линейной модели на кросс-валидации: 26.80

# %%
# Пайплайн для дерева решений
tree_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', DecisionTreeRegressor(random_state=42))
])

# %%
# Параметры для подбора гиперпараметров дерева решений
param_grid = {
    'model__max_depth': [3, 5, 7, 10, 15],  # добавляем 15 как новый параметр
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

# GridSearchCV для подбора гиперпараметров дерева решений
grid_search = GridSearchCV(estimator=tree_pipeline, param_grid=param_grid, cv=5, scoring=smape_scorer, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['employment_years',
#                                                                           'supervisor_evaluation',
#                                                                           'salary']),
#                                                                         ('onehot',
# ...

# %%
# Пайплайн для случайного леса
rf_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('model', RandomForestRegressor(random_state=42))
])

# Параметры для подбора гиперпараметров случайного леса
param_grid_rf = {
    'model__n_estimators': [100, 200],  # Количество деревьев в лесу
    'model__max_depth': [None, 10, 20],  # Максимальная глубина деревьев
    'model__min_samples_split': [2, 5],  # Минимальное количество образцов для разделения узла
    'model__min_samples_leaf': [1, 2]  # Минимальное количество образцов в листовом узле
}

# GridSearchCV для подбора гиперпараметров случайного леса
grid_search_rf = GridSearchCV(estimator=rf_pipeline, param_grid=param_grid_rf, cv=5, scoring=smape_scorer, n_jobs=-1)
grid_search_rf.fit(X_train, y_train)

# Лучшая модель случайного леса
best_rf_model = grid_search_rf.best_estimator_
print(f"SMAPE для лучшей модели случайного леса: {-grid_search_rf.best_score_:.2f}")
# Out:
# SMAPE для лучшей модели случайного леса: 13.83

# %%
# Лучшая модель после подбора гиперпараметров
best_tree_model = grid_search.best_estimator_

# Вывод результатов
print(f"SMAPE для лучшей модели дерева решений на кросс-валидации: {-grid_search.best_score_:.2f}")
print(f"Лучшие гиперпараметры для дерева решений: {grid_search.best_params_}")
# Out:
# SMAPE для лучшей модели дерева решений на кросс-валидации: 15.34
# Лучшие гиперпараметры для дерева решений: {'model__max_depth': 15, 'model__min_samples_leaf': 1, 'model__min_samples_split': 5}

# %%
# Разделение тестовых данных на признаки и целевой признак
X_test = test_data.drop(columns=['id', 'job_satisfaction_rate'])
y_test = test_data['job_satisfaction_rate']

# %%
# Предсказания лучшей модели на тестовой выборке
y_test_pred_best = best_tree_model.predict(X_test)

# Вычисление SMAPE для лучшей модели на тестовой выборке
smape_test_best = smape(y_test, y_test_pred_best)

print(f"SMAPE для лучшей модели на тестовой выборке: {smape_test_best:.2f}")
# Out:
# SMAPE для лучшей модели на тестовой выборке: 14.21
# D:\programs\python\anakonda\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Создание и обучение DummyRegressor
dummy_model = DummyRegressor(strategy='mean')
dummy_model.fit(X_train, y_train)

# Предсказания DummyRegressor на тестовой выборке
y_test_pred_dummy = dummy_model.predict(X_test)

# Вычисление SMAPE для DummyRegressor на тестовой выборке
smape_test_dummy = smape(test_target_job_satisfaction_rate['job_satisfaction_rate'], y_test_pred_dummy)

print(f"SMAPE для DummyRegressor на тестовой выборке: {smape_test_dummy:.2f}")

# Сравнение качества лучшей модели и DummyRegressor
if smape_test_best < smape_test_dummy:
    print("Лучшая модель превосходит DummyRegressor")
else:
    print("Лучшая модель не превосходит DummyRegressor")
# Out:
# SMAPE для DummyRegressor на тестовой выборке: 38.26
# Лучшая модель превосходит DummyRegressor

# %% [markdown]
# ### Вывод

# %% [markdown]
# - Линейная модель:
#
# SMAPE на кросс-валидации: 26.80
#
# - Дерево решений:
#
# SMAPE на кросс-валидации: 15.59
#
# SMAPE на тестовой выборке: 14.53
#
# - DummyRegressor:
#
# SMAPE на тестовой выборке: 38.26
#
# На основе метрики SMAPE, лучшая модель Дерево решений для предсказания уровня удовлетворённости работой

# %% [markdown]
# ### 6. Оформление выводов

# %% [markdown]
# Результаты моделей
#
# Линейная модель показала SMAPE 26.80 на кросс-валидации. Это значение значительно выше, чем у дерева решений, что указывает на худшую производительность линейной модели.
#
# Дерево решений с подобранными гиперпараметрами показало SMAPE 15.59 на кросс-валидации и 14.53 на тестовой выборке. Это значительно лучше, чем у линейной модели, и указывает на более высокую точность предсказаний.
#
# DummyRegressor, использующий среднее значение для предсказаний, показал SMAPE 38.26 на тестовой выборке. Это значение значительно выше, чем у дерева решений, что подтверждает, что дерево решений является более точной моделью.
#
# Лучшая модель: Дерево решений с подобранными гиперпараметрами.
# Дерево решений показало наилучшие результаты как на кросс-валидации, так и на тестовой выборке, с SMAPE 15.59 и 14.53 соответственно. Эти значения значительно лучше, чем у линейной модели и DummyRegressor, что указывает на более высокую точность предсказаний дерева решений.
# В дальнейшей работе следует использовать дерево решений с подобранными гиперпараметрами для предсказания уровня удовлетворенности работой, так как оно показало наилучшие результаты среди рассмотренных моделей.

# %% [markdown]
# ### Задача №2

# %% [markdown]
# ### 1. Загрузка данных

# %%
# Загрузка датафреймов
train_quit = pd.read_csv('https://code.s3.yandex.net/datasets/train_quit.csv') # Тренировочная выборка
test_features = pd.read_csv('https://code.s3.yandex.net/datasets/test_features.csv') # Входные признаки тестовой выборки
test_target_quit = pd.read_csv('https://code.s3.yandex.net/datasets/test_target_quit.csv') # Целевой признак тестовой выборки

# %%
# Общая информация для датасета train_quit
train_quit.info()
train_quit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# ...

# %% [markdown]
# В датасете 10 колонок и 4000 строк
# Типы данных соответствуют описанию
# Пропусков в данных предварительно нет

# %%
# Общая информация для датасета test_features
test_features.info()
test_features.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# ...

# %% [markdown]
# В датасете 9 колонок и 2000 строк
# В колонках dept и level строк меньше 2000, возможно это пропущенные значения
# Типы данных соответсвтуют своему описанию

# %%
# Общая информация для датасета test_target_quit
test_target_quit.info()
test_target_quit.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# В датасете 2 колонки и 2000 строк
# Пропусков в данных нет
# Типы данных соответствуют своему описанию

# %% [markdown]
# ### Вывод

# %% [markdown]
# Было загружено 3 датасета: train_quit, test_features.csv, test_target_quit
# В датасете test_features.csv есть пропуски в столбцах dept и level.
# Типы данных во всех датасетах соответсвуют действительности.
# Следующим шагом необходимо провести проверку данных на пропуски и дубликаты

# %% [markdown]
# ### 2. Предобработка данных

# %%
# Обзор уникальных значений
train_quit['level'].unique()
# Out:
# array(['middle', 'junior', 'sinior'], dtype=object)

# %%
# Исправляю артефакты
train_quit['level'] = train_quit['level'].str.replace('sinior', 'senior')
test_features['level'] = test_features['level'].str.replace('sinior', 'senior')

# %%
# Исправляю артефакты
test_features['level'] = test_features['level'].str.replace(' ', 'sales')

# %%
# Определение категориальных и числовых признаков
categorical_features = ['dept', 'level', 'workload', 'last_year_promo', 'last_year_violations']
numerical_features = ['employment_years', 'supervisor_evaluation', 'salary']

# %%
# Применение обученного пайплайна к столбцам 'level' и 'dept' в test_features
test_features[['level', 'dept']] = categorical_transformer.transform(test_features[['level', 'dept']])

# %%
# Проверка, что пропуски заполнены
print(test_features[['level', 'dept']].isnull().sum())
# Out:
# level    0
# dept     0
# dtype: int64

# %%
# Объединение датафреймов по колонке 'id'
test_df = pd.merge(test_features, test_target_quit, on='id')

# %%
# Общая информация для датасета test_df
test_df.info()
test_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   quit                   2000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 171.9+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# ...

# %%
# Создание словаря
dataframes = {
    'train_quit': train_quit,
    'test_df': test_df
}

# %%
# Вызов функции для вывода дубликатов
print_duplicates(dataframes)
# Out:
# Явные дубликаты в датафрейме train_quit:
# Явных дубликатов нет
#
#
# Явные дубликаты в датафрейме test_df:
# Явных дубликатов нет

# %%
# Вызов функции для нахождения неявных дубликатов
find_implicit_duplicates(dataframes)
# Out:
# Неявные дубликаты в датафрейме train_quit:
# Нет неявных дубликатов
#
#
# Неявные дубликаты в датафрейме test_df:
# Нет неявных дубликатов

# %% [markdown]
# ### Вывод

# %% [markdown]
# При обработке данных в датафрейме test_features были обнаружены пропущенные значения типа NaN.
# В столбцах level датафрейма test_features, значения sinior были изменены на senior.
# В столбце dept датафрейма test_features, значение ' ' было изменено на часто встречаемое sales.
# Пустые значения в столбцах level и dept в датафрейме test_features были заполнены с использованием пайплайна.
# Датафреймы проверены на наличие явных и неявных дубликатов. Дубликаты отсутствуют.
# Датафреймы test_features и test_target_quit были объединены с использованием функции merge по признаку id с созданием нового датафрейма test_df.

# %% [markdown]
# ### 3. Исследовательский анализ данных

# %%
# Вызов функции для построения всех графиков для каждого датафрейма
plot_all_graphs(dataframes['train_quit'])
# Out:
# Построение графиков для датафрейма:
# Построение графиков для категориального признака dept:
# Построение графиков для категориального признака level:
# Построение графиков для категориального признака workload:
# Построение графиков для дискретного признака employment_years:
# Построение графиков для категориального признака last_year_promo:
# Построение графиков для категориального признака last_year_violations:
# Построение графиков для дискретного признака supervisor_evaluation:
# Построение графиков для непрерывного признака salary:
# Построение графиков для категориального признака quit:

# %%
# Вызов функции для построения всех графиков для каждого датафрейма
plot_all_graphs(dataframes['test_df'])
# Out:
# Построение графиков для датафрейма:
# Построение графиков для категориального признака dept:
# Построение графиков для категориального признака level:
# Построение графиков для категориального признака workload:
# Построение графиков для дискретного признака employment_years:
# Построение графиков для категориального признака last_year_promo:
# Построение графиков для категориального признака last_year_violations:
# Построение графиков для дискретного признака supervisor_evaluation:
# Построение графиков для непрерывного признака salary:
# Построение графиков для категориального признака quit:

# %%
# Исключение колонки 'id'
train_data = train_quit.drop(columns=['id'])

# %%
# Проверка наличия дубликатов
duplicates = train_data.duplicated().sum()
print(f"Количество дубликатов в тренировочных данных: {duplicates}")
# Out:
# Количество дубликатов в тренировочных данных: 1413

# %%
# Удаление дубликатов
train_data = train_data.drop_duplicates()

# %%
# Проверка размера
train_data.shape
# Out:
# (2587, 9)

# %%
# Расчет матрицы корреляции phik
phik_matrix = train_data.phik_matrix(interval_cols=interval_cols)

# %%
# Построение тепловой карты
plt.figure(figsize=(16, 12))
sns.heatmap(phik_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Тепловая карта матрицы корреляции Phik')
plt.show()

# %%
# 1. Определим, в каком отделе с большей вероятностью работают уволившиеся сотрудники
dept_quit = train_quit[train_quit['quit'] == 'yes']['dept'].value_counts()
dept_stay = train_quit[train_quit['quit'] == 'no']['dept'].value_counts()

# %%
# Построим круговую диаграмму для уволившихся сотрудников
plt.figure(figsize=(8, 8))
plt.pie(dept_quit, labels=dept_quit.index, autopct='%1.1f%%', startangle=140, normalize=True)
plt.title('Распределение уволившихся сотрудников по отделам')
plt.show()

# Построим круговую диаграмму для оставшихся сотрудников
plt.figure(figsize=(8, 8))
plt.pie(dept_stay, labels=dept_stay.index, autopct='%1.1f%%', startangle=140, normalize=True)
plt.title('Распределение оставшихся сотрудников по отделам')
plt.show()

# %% [markdown]
# Количество уволившихся и оставшихся сотрудников приблизительно одинаковое
# Больше всех людей уволилось из самого большого отдела - отдела продаж

# %%
# 2. Определим уровень загруженности уволившихся сотрудников
workload_quit = train_quit[train_quit['quit'] == 'yes']['workload'].value_counts()
workload_stay = train_quit[train_quit['quit'] == 'no']['workload'].value_counts()

# Построим круговую диаграмму для уволившихся сотрудников
plt.figure(figsize=(8, 8))
plt.pie(workload_quit, labels=workload_quit.index, autopct='%1.1f%%', startangle=140, normalize=True)
plt.title('Распределение уволившихся сотрудников по уровню загруженности')
plt.show()

# Построим круговую диаграмму для оставшихся сотрудников
plt.figure(figsize=(8, 8))
plt.pie(workload_stay, labels=workload_stay.index, autopct='%1.1f%%', startangle=140, normalize=True)
plt.title('Распределение оставшихся сотрудников по уровню загруженности')
plt.show()

# %% [markdown]
# больше всех сотрудников уволилось по уровню загруженности low

# %%
# 3. Сравним среднее значение зарплаты ушедших сотрудников с теми, кто остался в компании
salary_quit = train_quit[train_quit['quit'] == 'yes']['salary']
salary_stay = train_quit[train_quit['quit'] == 'no']['salary']

# Построим нормированные гистограммы для сравнения зарплат
plt.figure(figsize=(12, 6))
sns.histplot(salary_quit, kde=True, color='red', label='Уволившиеся', bins=30, stat='density', common_norm=False)
sns.histplot(salary_stay, kde=True, color='blue', label='Оставшиеся', bins=30, stat='density', common_norm=False)
plt.title('Распределение зарплат уволившихся и оставшихся сотрудников')
plt.xlabel('Зарплата')
plt.ylabel('Плотность распределения')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# низкооплачиваемые сотрудники с большей охотой увольняются, чем с высокооплачиваемой

# %%
# Вывод средних значений зарплат
print(f"Средняя зарплата уволившихся сотрудников: {salary_quit.mean():.2f}")
print(f"Средняя зарплата оставшихся сотрудников: {salary_stay.mean():.2f}")
# Out:
# Средняя зарплата уволившихся сотрудников: 23885.11
# Средняя зарплата оставшихся сотрудников: 37702.23

# %%
# Круговая диаграмма для признака 'dept'
plt.figure(figsize=(8, 6))
train_quit['dept'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по отделам')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'level'
plt.figure(figsize=(8, 6))
train_quit['level'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по уровням')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'workload'
plt.figure(figsize=(8, 6))
train_quit['workload'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по уровню загруженности')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'last_year_promo'
plt.figure(figsize=(8, 6))
train_quit['last_year_promo'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по наличию повышения в прошлом году')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'last_year_violations'
plt.figure(figsize=(8, 6))
train_quit['last_year_violations'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по наличию нарушений в прошлом году')
plt.ylabel('')
plt.show()

# Преобразование признака 'salary' в интервалы
salary_bins = [0, 20000, 40000, 80000, 110000]
salary_labels = ['0-20k', '20k-40k', '40k-80k', '80k-110k']
train_quit['salary_binned'] = pd.cut(train_quit['salary'], bins=salary_bins, labels=salary_labels)

# Круговая диаграмма для признака 'employment_years'
plt.figure(figsize=(8, 6))
employment_years_counts = train_quit['employment_years'].value_counts()
employment_years_counts.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по количеству лет работы')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'supervisor_evaluation'
plt.figure(figsize=(8, 6))
supervisor_evaluation_counts = train_quit['supervisor_evaluation'].value_counts()
supervisor_evaluation_counts.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по оценке руководителя')
plt.ylabel('')
plt.show()

# Круговая диаграмма для признака 'salary'
plt.figure(figsize=(8, 6))
salary_counts = train_quit['salary_binned'].value_counts()
salary_counts.plot.pie(autopct='%1.1f%%', startangle=90, cmap='Pastel1')
plt.title('Распределение сотрудников по уровню зарплаты')
plt.ylabel('')
plt.show()

# %% [markdown]
# Отдел, в котором работает сотрудник, может существенно влиять на его решение уйти из компании. Разные отделы могут иметь различные условия работы, культуру и уровень стресса, что может повлиять на удовлетворенность сотрудников и их решение остаться или уйти. Большинство сотрудников находится в отделе продаж и технологическом отделе.
#
# Уровень сотрудника показывает его позицию в компании и может влиять на его решение уйти. Более высокие уровни могут быть связаны с более высокими ожиданиями и стрессом, что может привести к уходу. Большинство сотрудников находятся на уровне junior, меньше всего на уровне senior.
#
# Загруженность сотрудников напрямую влияет на их удовлетворенность работой. Высокий уровень загруженности может привести к выгоранию и, как следствие, к уходу из компании. Средняя загруженность у большинства сотрудников, однако высокая нагрузка у 16.9%.
#
# Наличие повышения в прошлом году может влиять на решение сотрудника остаться в компании. Сотрудники, которые не получили повышение, могут чувствовать себя недооцененными и искать возможности в других компаниях. Всего 2.8% сотрудников были повышены в прошлом году.
#
# Наличие нарушений в прошлом году может указывать на проблемы с дисциплиной или удовлетворенностью работой. Сотрудники с нарушениями могут быть более склонны к уходу из компании. 13.6% сотрудников имеют нарушения в трудовом кодексе с компанией.
#
# Количество лет работы в компании может влиять на решение сотрудника уйти. Сотрудники, которые работают дольше, могут чувствовать себя усталыми или искать новые возможности. Больше всего в компании новичков, на позиции junior.
#
# Оценка руководителя может влиять на удовлетворенность сотрудника работой. Низкая оценка может указывать на проблемы с производительностью или удовлетворенностью, что может привести к уходу. Чаще всего руководители оценивают сотрудников на 4 балла.
#
# Уровень зарплаты является важным фактором, влияющим на решение сотрудника остаться в компании. Низкая зарплата может привести к неудовлетворенности и поиску других возможностей. Большинство сотрудников имеют низкую зарплату.

# %%
# Объединение датафреймов по колонке 'id' для тестовой выборки
test_combined = pd.merge(test_features, test_target_job_satisfaction_rate, on='id')
test_combined = pd.merge(test_combined, test_target_quit, on='id')

# %%
# Проверка результата
test_combined.info()
test_combined.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   2000 non-null   object
#  2   level                  2000 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
#  9   job_satisfaction_rate  2000 non-null   float64
#  10  quit                   2000 non-null   object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 187.5+ KB
#        id       dept   level workload  employment_years last_year_promo  \
# ...

# %%
# Уровень удовлетворённости уволившихся сотрудников
satisfaction_quit = test_combined[test_combined['quit'] == 'yes']['job_satisfaction_rate']
# Уровень удовлетворённости оставшихся сотрудников
satisfaction_stay = test_combined[test_combined['quit'] == 'no']['job_satisfaction_rate']

# Построим нормированные гистограммы для сравнения уровня удовлетворённости
plt.figure(figsize=(12, 6))
sns.histplot(satisfaction_quit, kde=True, color='red', label='Уволившиеся', bins=30, stat='density', common_norm=False)
sns.histplot(satisfaction_stay, kde=True, color='blue', label='Оставшиеся', bins=30, stat='density', common_norm=False)
plt.title('Распределение уровня удовлетворённости уволившихся и оставшихся сотрудников')
plt.xlabel('Уровень удовлетворённости')
plt.ylabel('Плотность распределения')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Нулевая гипотеза (H0): Нет статистически значимого различия в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников.
#
# Альтернативная гипотеза (H1): Есть статистически значимое различие в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников.

# %%
# t-тест для сравнения распределений уровня удовлетворённости
t_stat, p_value = ttest_ind(satisfaction_quit, satisfaction_stay, equal_var=False)

print(f"t-статистика: {t_stat:.2f}")
print(f"p-значение: {p_value:.2e}")

if p_value < 0.05:
    print("Различие в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников статистически значимо.")
else:
    print("Различие в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников не является статистически значимым.")
# Out:
# t-статистика: -23.80
# p-значение: 2.77e-101
# Различие в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников статистически значимо.

# %% [markdown]
# Распределение уровня удовлетворённости уволившихся сотрудников смещено влево, что указывает на более низкие значения удовлетворённости.
# Распределение уровня удовлетворённости оставшихся сотрудников более равномерно и смещено вправо, что указывает на более высокие значения удовлетворённости.
#
# Отрицательное значение t-статистики указывает на то, что средний уровень удовлетворённости уволившихся сотрудников значительно ниже, чем у оставшихся сотрудников.
#
# p-значение (2.77e-101) значительно меньше 0.05, что указывает на статистически значимое различие между распределениями уровня удовлетворённости уволившихся и оставшихся сотрудников.
#
# Различие в распределениях уровня удовлетворённости уволившихся и оставшихся сотрудников статистически значимо.
# Это подтверждает утверждение аналитиков о том, что уровень удовлетворённости сотрудника работой в компании влияет на вероятность его увольнения.

# %% [markdown]
# ### 4. Добавление нового входного признака

# %%
# Разделение тренировочных данных на признаки и целевой признак
X_train_quit = train_quit.drop(columns=['id', 'quit'])
y_train_quit = train_quit['quit']

# Разделение тестовых данных на признаки и целевой признак
X_test_quit = test_features.drop(columns=['id'])
y_test_quit = test_target_quit.merge(test_features['id'], on='id', how='right')['quit']

# %%
# Использование лучшей модели (дерево решений) для предсказания job_satisfaction_rate на тренировочной выборке
y_train_pred_job_satisfaction = best_tree_model.predict(X_train_quit)

# Добавление предсказанного job_satisfaction_rate к тренировочным данным второй задачи
X_train_quit_with_job_satisfaction = X_train_quit
X_train_quit_with_job_satisfaction['predicted_job_satisfaction_rate'] = y_train_pred_job_satisfaction

# Использование лучшей модели (дерево решений) для предсказания job_satisfaction_rate на тестовой выборке
y_test_pred_job_satisfaction = best_tree_model.predict(X_test_quit)

# Добавление предсказанного job_satisfaction_rate к тестовым данным второй задачи
X_test_quit_with_job_satisfaction = X_test_quit
X_test_quit_with_job_satisfaction['predicted_job_satisfaction_rate'] = y_test_pred_job_satisfaction
# Out:
# D:\programs\python\anakonda\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Кодирование целевого признака
le = LabelEncoder()
le.fit(['no', 'yes'])
le.classes_ = np.array(['no', 'yes'])
y_train_quit = le.transform(y_train_quit)

# Кодирование целевого признака в тестовых данных
y_test_quit = le.transform(y_test_quit)

# %% [markdown]
# ### 5. Подготовка данных

# %%
# Определение числовых признаков, включая новый признак, предсказанный моделью из предыдущей задачи
numerical_features_quit = ['employment_years', 'supervisor_evaluation', 'salary', 'predicted_job_satisfaction_rate']

# %%
# Разделение категориальных признаков на те, которые будут кодироваться OneHotEncoder и OrdinalEncoder
onehot_features_quit = ['dept', 'last_year_promo', 'last_year_violations']
ordinal_features_quit = ['level', 'workload']

# %%
# Пайплайн для категориальных признаков, которые будут кодироваться OneHotEncoder
onehot_transformer_quit = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore', drop='first'))
])

# Пайплайн для категориальных признаков, которые будут кодироваться OrdinalEncoder
ordinal_transformer_quit = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(categories=[
        ['junior', 'middle', 'senior'],
        ['medium', 'high', 'low']
    ], handle_unknown='use_encoded_value', unknown_value=-1))
])

# Пайплайн для числовых признаков
numerical_transformer_quit = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
# Объединение пайплайнов в ColumnTransformer
preprocessor_quit = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer_quit, numerical_features_quit),
        ('onehot', onehot_transformer_quit, onehot_features_quit),
        ('ordinal', ordinal_transformer_quit, ordinal_features_quit)
    ])

# %%
X_train_quit_prepared = preprocessor_quit.fit_transform(X_train_quit_with_job_satisfaction)
X_test_quit_prepared = preprocessor_quit.transform(X_test_quit)
# Out:
# D:\programs\python\anakonda\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %% [markdown]
# ### 6. Обучение модели

# %%
# Модель 1: Логистическая регрессия
logreg = LogisticRegression(random_state=42)
roc_auc_logreg = cross_val_score(logreg, X_train_quit_prepared, y_train_quit, cv=5, scoring='roc_auc').mean()

# Модель 2: Случайный лес
rf = RandomForestClassifier(random_state=42)
param_grid_rf = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2]
}
grid_search_rf = GridSearchCV(rf, param_grid_rf, cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_rf.fit(X_train_quit_prepared, y_train_quit)
best_rf = grid_search_rf.best_estimator_
roc_auc_rf = grid_search_rf.best_score_

# Модель 3: SVM
svc = SVC(probability=True, random_state=42)
param_grid_svc = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf']
}
grid_search_svc = GridSearchCV(svc, param_grid_svc, cv=5, scoring='roc_auc', n_jobs=-1)
grid_search_svc.fit(X_train_quit_prepared, y_train_quit)
best_svc = grid_search_svc.best_estimator_
roc_auc_svc = grid_search_svc.best_score_

print(f"ROC-AUC для Логистической регрессии: {roc_auc_logreg:.4f}")
print(f"ROC-AUC для Случайного леса: {roc_auc_rf:.4f}")
print(f"ROC-AUC для SVM: {roc_auc_svc:.4f}")
# Out:
# ROC-AUC для Логистической регрессии: 0.9278
# ROC-AUC для Случайного леса: 0.9394
# ROC-AUC для SVM: 0.9285

# %%
# Выбор лучшей модели
best_model = None
best_roc_auc = 0
if roc_auc_logreg > best_roc_auc:
    best_model = logreg
    best_roc_auc = roc_auc_logreg
if roc_auc_rf > best_roc_auc:
    best_model = best_rf
    best_roc_auc = roc_auc_rf
if roc_auc_svc > best_roc_auc:
    best_model = best_svc
    best_roc_auc = roc_auc_svc

print(f"Лучшая модель: {best_model.__class__.__name__} с ROC-AUC: {best_roc_auc:.4f}")
# Out:
# Лучшая модель: RandomForestClassifier с ROC-AUC: 0.9394

# %%
# Применение предобработки к тестовым данным
X_test_quit_prepared = preprocessor_quit.transform(X_test_quit)

# Предсказание вероятностей классов с использованием лучшей модели
y_pred_best_model = best_model.predict_proba(X_test_quit_prepared)[:, 1]

# Вычисление ROC-AUC на тестовой выборке
roc_auc_best_model = roc_auc_score(y_test_quit, y_pred_best_model)

# Вывод значения ROC-AUC для лучшей модели на тестовой выборке
print(f"ROC-AUC для лучшей модели на тестовой выборке: {roc_auc_best_model:.4f}")
# Out:
# ROC-AUC для лучшей модели на тестовой выборке: 0.9308
# D:\programs\python\anakonda\Lib\site-packages\sklearn\preprocessing\_encoders.py:241: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
# Создание и обучение DummyClassifier
dummy_clf = DummyClassifier(strategy='most_frequent', random_state=42)
dummy_clf.fit(X_train_quit_prepared, y_train_quit)

# Предсказания на тестовой выборке
y_pred_dummy = dummy_clf.predict_proba(X_test_quit_prepared)[:, 1]

# Оценка качества модели DummyClassifier
roc_auc_dummy = roc_auc_score(y_test_quit, y_pred_dummy)

print(f"ROC-AUC для DummyClassifier: {roc_auc_dummy:.4f}")
# Out:
# ROC-AUC для DummyClassifier: 0.5000

# %% [markdown]
# ### 7. Выводы

# %% [markdown]
# 1. На основании представленных результатов, три модели были оценены по метрике ROC-AUC на тренировочной выборке:
#
# - Логистическая регрессия:
#
# ROC-AUC: 0.9276
# Логистическая регрессия показала высокую способность различать между классами, но не наивысшую среди всех моделей.
#
# - Случайный лес:
#
# ROC-AUC: 0.9401
# Случайный лес продемонстрировал наивысшее значение ROC-AUC среди всех трех моделей, что указывает на его превосходную способность различать между классами.
#
# - SVM (Support Vector Machine):
#
# ROC-AUC: 0.9282
# SVM также показал высокое значение ROC-AUC, но немного уступил случайному лесу.
#
# 2. На основании значений ROC-AUC, лучшей моделью была выбрана модель случайного леса (RandomForestClassifier) с ROC-AUC: 0.9401. Эта модель показала наивысшую способность различать между классами на тренировочной выборке.
#
# 3. После выбора лучшей модели, она была применена к тестовой выборке:
#
# ROC-AUC для лучшей модели на тестовой выборке: 0.9291
#
# Случайный лес показал наивысшее значение ROC-AUC на тренировочной выборке (0.9401), что указывает на его превосходную способность различать между классами.
# Случайный лес продемонстрировал высокую стабильность и способность обобщать на новых данных благодаря своей структуре, состоящей из множества деревьев решений.
# Случайный лес эффективно справляется с различными типами данных и признаков, что делает его универсальным инструментом для задач классификации.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Целью данного исследования было разработать модели для предсказания уровня удовлетворённости сотрудников и вероятности их увольнения из компании. В рамках первой задачи необходимо было предсказать уровень удовлетворённости сотрудников, используя различные модели машинного обучения. Во второй задаче необходимо было исследовать возможность предсказания увольнения сотрудников, учитывая предсказанный уровень удовлетворённости и другие важные признаки.
#
# Этапы работы
#
# - Задача №1: Предсказание уровня удовлетворённости сотрудника
#
# Шаг 1. Загрузка данных: Были загружены тренировочные данные, входные признаки тестовой выборки и целевой признак тестовой выборки.
#
# Шаг 2. Предобработка данных: Проведено изучение данных, выполнена предобработка, включая заполнение пропусков в пайплайне.
# При обработке данных в датафреймах train_job_satisfaction_rate и test_features были обнаружены пропущенные значения типа NaN.
# В столбцах level датафрейма train_job_satisfaction_rate и test_features, значения s<font color='red'>i</font>nior были изменены на senior.
# В столбце dept датафрейма test_features, значение ' ' было изменено на часто встречаемое sales.
# Пустые значения в столбцах level и dept в датафреймах train_job_satisfaction_rate и test_features были заполнены с использованием пайплайна.
#
# Шаг 3. Исследовательский анализ данных: Проведен анализ признаков для выявления их значимости и подготовки к моделированию.
# Для датафреймов train_job_satisfaction_rate и test_data были построены графики для анализа данных и тепловые карты корреляции.
#
# Шаг 4. Подготовка данных: Признаки были подготовлены в пайплайне, с использованием как минимум двух кодировщиков, учитывая особенности признаков моделей.
#
# Шаг 5. Обучение моделей: Были обучены две модели: линейная модель и модель дерева решений. Для одной из моделей были подобраны гиперпараметры. Лучшая модель была выбрана на основе метрики SMAPE, и её качество было проверено на тестовой выборке.
#
# Линейная модель продемонстрировала SMAPE 26.80 на кросс-валидации. Это значение значительно выше, чем у модели дерева решений, что указывает на менее точные предсказания линейной модели.
#
# Модель дерева решений с подобранными гиперпараметрами показала SMAPE 15.59 на кросс-валидации и 14.53 на тестовой выборке. Эти результаты значительно лучше, чем у линейной модели, что свидетельствует о более высокой точности предсказаний модели дерева решений.
#
# DummyRegressor, использующий среднее значение для предсказаний, показал SMAPE 38.26 на тестовой выборке. Это значение существенно выше, чем у модели дерева решений, что подтверждает, что дерево решений является более точной моделью.
#
# Модель дерева решений показала наилучшие результаты как на кросс-валидации, так и на тестовой выборке, с SMAPE 15.59 и 14.53 соответственно. Эти значения значительно лучше, чем у линейной модели и DummyRegressor, что указывает на более высокую точность предсказаний дерева решений. В дальнейшем следует использовать модель дерева решений с подобранными гиперпараметрами для предсказания уровня удовлетворённости сотрудников, так как она показала наилучшие результаты среди рассмотренных моделей.
#
# Шаг 6. Оформление выводов: Сделаны промежуточные выводы о том, какая модель справилась лучше и почему.
#
# - Задача №2: Предсказание увольнения сотрудника из компании
#
# Шаг 1. Загрузка данных: Были загружены тренировочные данные, входные признаки тестовой выборки и целевой признак тестовой выборки.
#
# Шаг 2. Предобработка данных: Проведено изучение данных и заполнение пропусков в пайплайне.
#
# Шаг 3. Исследовательский анализ данных:
# Проведен исследовательский анализ данных.
# Составлен портрет «уволившегося сотрудника», включая анализ отдела, уровня загруженности и сравнение зарплат ушедших и оставшихся сотрудников.
# Проверено утверждение о влиянии уровня удовлетворённости на увольнение, визуализированы и сравнены распределения признака job_satisfaction_rate для ушедших и оставшихся сотрудников.
#
# Шаг 4. Добавление нового входного признака: Добавлен предсказанный уровень удовлетворённости (job_satisfaction_rate) к входным признакам второй задачи.
#
# Шаг 5. Подготовка данных: Признаки были подготовлены в пайплайне, с использованием как минимум двух кодировщиков, учитывая особенности признаков и моделей.
#
# Шаг 6. Обучение модели: Были обучены три модели, для двух из них подобраны гиперпараметры. Качество лучшей модели проверено на основе метрики ROC-AUC.
#
# Модель логистической регрессии показала ROC-AUC 0.9276. Хотя это значение выше порогового значения 0.91, оно оказалось ниже, чем у других моделей, что указывает на её меньшую точность в предсказании увольнения сотрудников.
#
# Модель случайного леса продемонстрировала наивысшее значение ROC-AUC 0.9401. Это указывает на её высокую точность и способность эффективно предсказывать увольнение сотрудников. Подбор гиперпараметров позволил улучшить качество модели, что подтверждается наивысшим значением ROC-AUC среди всех рассмотренных моделей.
#
# Модель SVM показала ROC-AUC 0.9282, что также является высоким значением, превышающим порог 0.91. Однако, несмотря на хорошие результаты, модель случайного леса показала лучшие результаты.
#
# Шаг 7. Выводы о том, какая модель справилась лучше и почему.
# На основании проведенного анализа и оценки качества моделей, модель случайного леса была выбрана как лучшая для предсказания увольнения сотрудников из компании. Её высокая точность, продемонстрированная наивысшим значением ROC-AUC 0.9291 на тестовой выборке, и способность учитывать сложные зависимости в данных делают её наиболее подходящей для данной задачи. Подбор гиперпараметров дополнительно улучшил её производительность, что подтверждает её превосходство над логистической регрессией и SVM.
#
# Оценка модели на адекватность с использованием DummyClassifier показала значение ROC-AUC 0.5000, что подтверждает, что модель случайного леса имеет значительно более высокую производительность на этапе кросс-валидации
#
# Предложения для бизнеса
#
# Задача №1: Предсказание уровня удовлетворённости сотрудника
#
# Лучшая модель для предсказания уровня удовлетворённости сотрудников оказалась модель дерева решений, которая показала SMAPE ≤ 15 на тестовой выборке.
# Линейная модель показала худшие результаты по сравнению с деревом решений, что может быть связано с нелинейными зависимостями в данных.
#
# Задача №2: Предсказание увольнения сотрудника из компании
#
# Лучшая модель для предсказания увольнения сотрудников оказалась модель случайного леса, которая показала ROC-AUC ≥ 0.91 на тестовой выборке.
# Включение предсказанного уровня удовлетворённости сотрудников в качестве признака улучшило качество модели, что подтверждает важность этого признака для предсказания увольнения.
# Анализ данных показал, что отдел, уровень загруженности, зарплата и уровень удовлетворённости являются важными факторами, влияющими на решение сотрудников уйти из компании.
#
# Использовать модель дерева решений для предсказания уровня удовлетворённости сотрудников, что позволит своевременно выявлять сотрудников с низким уровнем удовлетворённости и принимать меры для повышения их удовлетворённости.
# Использовать модель случайного леса для предсказания увольнения сотрудников, что позволит компании предсказывать потенциальные увольнения и принимать меры для удержания ценных сотрудников.
#
# Разработать программы повышения удовлетворённости сотрудников, особенно в отделах с высокой текучестью кадров и среди сотрудников с высокой загруженностью и низкой зарплатой (отдел продаж и разработки).

# %% [markdown]
# Ссылка на репозиторий: https://github.com/Lekar17/сборный проект-2
